# %%
from IPython.display import Image

# %%
# !pip install ultralytics==8.0.0

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.__version__
# Out:
# '2.1.0+cu121'

# %% [markdown]
# **Object** **Detection**

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/img.19.44 AM.jpeg'
# Out:
# 2024-02-23 21:43:56.979116: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 21:43:56.979166: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 21:43:56.980345: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 21:43:58.045775: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# ...

# %%
from ultralytics import YOLO

# %%
# initializing YOLO with model name
model = YOLO('yolov8m.pt')

# predict the results from this model
model.predict(source='/content/WhatsApp Image 2024-02-24 at 12.19.44 AM.jpeg', save=True, conf=0.5)
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8m summary: 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/WhatsApp Image 2024-02-24 at 12.19.44 AM.jpeg: 448x640 11 persons, 1 bicycle, 1 bus, 1 traffic light, 1 backpack, 3 handbags, 296.9ms
# Speed: 0.7ms pre-process, 296.9ms inference, 943.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# [tensor([[2.24000e+02, 3.09000e+02, 4.34000e+02, 6.59000e+02, 9.09668e-01, 0.00000e+00],
#          [9.45000e+02, 3.38000e+02, 9.99000e+02, 5.55000e+02, 9.00879e-01, 0.00000e+00],
#          [2.96000e+02, 1.75000e+02, 7.79000e+02, 4.67000e+02, 8.84766e-01, 5.00000e+00],
#          [7.38000e+02, 3.37000e+02, 8.70000e+02, 6.61000e+02, 8.83789e-01, 0.00000e+00],
#          [5.89000e+02, 3.67000e+02, 6.72000e+02, 6.61000e+02, 8.74512e-01, 0.00000e+00],
# ...

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/WhatsApp Image 2024-02-24 at 12.19.44 AM.jpeg' save_crop=True
# Out:
# 2024-02-23 21:12:27.211181: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 21:12:27.211231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 21:12:27.212763: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 21:12:28.247630: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# ...

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/WhatsApp Image 2024-02-24 at 12.19.44 AM.jpeg' hide_labels=True hide_conf=True
# Out:
# 2024-02-23 21:16:53.269757: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 21:16:53.269810: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 21:16:53.271654: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 21:16:54.713927: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# ...

# %% [markdown]
# **Object Detection on Video**

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/demo.mp4'
# Out:
# 2024-02-23 21:31:50.168823: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 21:31:50.168871: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 21:31:50.170087: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 21:31:51.225051: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# ...

# %% [markdown]
# **Semantic Segmetation Model**

# %%
# !yolo task=segment mode=predict model=yolov8s-seg.pt source='/content/img.19.44 AM.jpeg'
# Out:
# 2024-02-23 21:37:47.187464: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-23 21:37:47.187518: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-23 21:37:47.188879: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-23 21:37:48.232618: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
# 100% 22.8M/22.8M [00:00<00:00, 233MB/s]
#
# Fusing layers...
# YOLOv8s-seg summary: 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
# ...
